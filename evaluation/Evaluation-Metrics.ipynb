# %%
# basics
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import datetime

# corpus metrics
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu

# keras utilities
from keras.models import load_model

# image processing
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw 

# custom classes

# %load_ext autoreload
# %autoreload 2

from sequence_candidate import SequenceCandidate
from beam_predict import generate_predictions_beam

# subprocesses 
import dask.dataframe as dd
from dask.multiprocessing import get
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Evaluation Metrics
#
# As part of this project, I've trained three different models with three different architectures. When presenting the efficacy of each of these models, it will be useful to report standard metrics used to guage the effectiveness of machine translation and image captioning systems. In this notebook, I compute these metrics.

# %% [markdown]
# ## 1. Load validation data.
#
# I'll need to preduct the captions of the validation images. To do so, I'll need to load the pre-computed photo-features, as well as the true captions themselves.

# %%
# Load the validation features
with open("../data/features/valid_features.pkl", "rb") as handle:
    valid_features = pickle.load(handle)
handle.close()

# %%
# each entry is a tuple with the features as a 4096 dimensional array. 
valid_features["_ExrVJTjGcChfzLH51etAw"][0].shape
# Out:
# (4096,)

# %%
# Load the true validation captions
valid_captions = pd.read_csv("../data/split_lists/valid_ids.csv")

# %%
valid_captions.head()
# Out:
#                  photo_id                 caption
# 0  _ExrVJTjGcChfzLH51etAw  shanghai rainbow trout
# 1  yPUPhsJvT6yx6l8QwShw1Q     grill rainbow trout
# 2  zvESg-w2JIBL5FhU7F2d-g            chicken parm
# 3  uqdXqfB8MXW6XU7Hk1gGIQ        mcg holiday jazz
# 4  VMedbsDZnCxmCE3Pndvtng             dining room

# %% [markdown]
# ## 2. Load the Tokenizer and Models
#
# Used to predict new captions

# %%
with open("../data/tokenizer/tokenizer.pkl","rb") as handle:
    tokenizer = pickle.load(handle)
handle.close()

# %%
# see if loaded properly - should be 30212
1 + len(tokenizer.word_index)
# Out:
# 30212

# %%
# create a dictionary of {index:word} pairs instead of {word:index} pairs
reverse_tokenizer = {index: word for word,index in tokenizer.word_index.items()}

# %%
# Merge-Concat model
merge_concat = load_model("models/model_merge-date_5-18-14-40-ep016-loss4.704_lr-0.010000_patience-3.h5")
# Merge-Add model
merge_add = load_model("models/model_merge_add-date_6-4-14-11-ep014-loss4.864_lr-0.010000_patience-3.h5")
# Inject model
inject = load_model("models/model_inject-date_5-16-15-45-ep030-loss5.009_lr-0.010000_patience-3.h5")
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.

# %% [markdown]
# Now, print the summary of each of these models just to see that everything loaded ok.

# %%
merge_concat.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs-photo (InputLayer)       (None, 4096)         0
# __________________________________________________________________________________________________
# Inputs-caption (InputLayer)     (None, 15)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         16781312    Inputs-photo[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 15, 300)      9063600     Inputs-caption[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4096)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 15, 300)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          1048832     dropout_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          570368      dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           dense_2[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          131328      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30212)        7764484     dense_3[0][0]
# ==================================================================================================
# Total params: 35,359,924
# Trainable params: 26,296,324
# Non-trainable params: 9,063,600
# __________________________________________________________________________________________________

# %%
merge_add.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs-photo (InputLayer)       (None, 4096)         0
# __________________________________________________________________________________________________
# Inputs-caption (InputLayer)     (None, 15)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         16781312    Inputs-photo[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 15, 300)      9063600     Inputs-caption[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4096)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 15, 300)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          1048832     dropout_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          570368      dropout_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256)          0           dense_2[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          65792       add_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30212)        7764484     dense_3[0][0]
# ==================================================================================================
# Total params: 35,294,388
# Trainable params: 26,230,788
# Non-trainable params: 9,063,600
# __________________________________________________________________________________________________

# %%
inject.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs-photo (InputLayer)       (None, 4096)         0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4096)         0           Inputs-photo[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 300)          1229100     dropout_1[0][0]
# __________________________________________________________________________________________________
# Inputs-caption (InputLayer)     (None, 15)           0
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 1, 300)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 15, 300)      9063600     Inputs-caption[0][0]
# __________________________________________________________________________________________________
# masking_1 (Masking)             (None, 1, 300)       0           repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 15, 300)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 300)      0           masking_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 300)          721200      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30212)        9093812     dropout_3[0][0]
# ==================================================================================================
# Total params: 20,107,712
# Trainable params: 11,044,112
# Non-trainable params: 9,063,600
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. Generate predictions
#
# now, for each of the three models, and for values of $\alpha$ equal to .6, .7, .8, I'll generate preictions using the top result from a beam search witha with of 3.

# %%
tmp = valid_captions.head(100)

# %%
str(int(.9*10))
# Out:
# '9'

# %%
def add_predictions(df):
    # set up the models you will run
    models = [merge_concat, merge_add, inject]
    model_names = ["merge_concat", "merge_add", "inject"]
    alpha_range = [.6, .7, .8]
    for i in range(len(models)):
        for alpha in alpha_range:
            # set up a column name 
            colname = "_".join([model_names[i], str(int(alpha*10)), 'pred'])
            df[colname] = df.photo_id.apply(lambda x:
                            generate_predictions_beam(img_id = x, features= valid_features, 
                                caption_model=models[i], 
                                  reverse_tokenizer=reverse_tokenizer,
                                  width = 3, num_neighbors = 5, top_n = 1,
                                  alpha = alpha)[0][0])
            print("done: alpha = %f, model = %s, time: %s" %(alpha, model_names[i], str(datetime.datetime.now())))
    return df

# %%
# %time df_full = add_predictions(valid_captions)
# Out:
# done: alpha = 0.600000, model = merge_concat, time: 2018-06-06 12:30:17.056013
# done: alpha = 0.700000, model = merge_concat, time: 2018-06-06 14:54:22.595789
# done: alpha = 0.800000, model = merge_concat, time: 2018-06-06 17:18:29.722129
# done: alpha = 0.600000, model = merge_add, time: 2018-06-07 09:53:36.759282
# done: alpha = 0.700000, model = merge_add, time: 2018-06-07 12:17:59.764359
# done: alpha = 0.800000, model = merge_add, time: 2018-06-07 14:42:26.749322
# done: alpha = 0.600000, model = inject, time: 2018-06-07 16:52:56.618600
# done: alpha = 0.700000, model = inject, time: 2018-06-07 19:03:29.067348
# done: alpha = 0.800000, model = inject, time: 2018-06-07 21:14:03.783476
# CPU times: user 1d 12h 9min 41s, sys: 4h 31min 46s, total: 1d 16h 41min 28s
# Wall time: 1d 11h 8min 8s

# %%
df_full.to_csv("df_full.csv")

# %% [markdown]
# ## 4. Calculate BLEU scores

# %%
def bleu1(ref, cand):
    return sentence_bleu([ref.split()], cand.split(), weights=(1.0, 0, 0, 0))

def bleu2(ref, cand):
    return sentence_bleu([ref.split()], cand.split(), weights=(.5, .5, 0, 0))

def bleu3(ref, cand):
    return sentence_bleu([ref.split()], cand.split(), weights=(.33, .33, .33, 0))

def bleu4(ref, cand):
    return sentence_bleu([ref.split()], cand.split(), weights=(.25, .25, .25, .25))

# %%
pred_cols = df_full.columns[2:]
print(pred_cols)
# Out:
# Index(['merge_concat_6_pred', 'merge_concat_7_pred', 'merge_concat_8_pred',
#        'merge_add_6_pred', 'merge_add_7_pred', 'merge_add_8_pred',
#        'inject_6_pred', 'inject_7_pred', 'inject_8_pred'],
#       dtype='object')

# %%
df_full.apply(lambda row: bleu1(str(row["caption"]), str(row["merge_concat_6_pred"])), axis = 1)
# Out:
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 0        0.000000
# 1        0.000000
# 2        0.090909
# 3        0.000000
# 4        0.500000
# 5        1.000000
# 6        0.000000
# 7        0.090909
# 8        0.000000
# 9        0.000000
# 10       0.090909
# 11       0.000000
# 12       0.000000
# 13       0.000000
# 14       0.606531
# 15       0.000000
# 16       0.000000
# 17       0.000000
# 18       0.000000
# 19       0.000000
# 20       0.500000
# 21       0.000000
# 22       0.000000
# 23       0.500000
# 24       0.000000
# 25       0.402192
# 26       0.000000
# 27       0.000000
# 28       0.000000
# 29       0.072433
#            ...
# 20132    0.000000
# 20133    0.000000
# 20134    0.000000
# 20135    0.000000
# 20136    0.000000
# 20137    0.303265
# 20138    0.000000
# 20139    0.000000
# 20140    0.181818
# 20141    0.083009
# 20142    0.000000
# 20143    0.123840
# 20144    0.151633
# 20145    0.250000
# 20146    0.000000
# 20147    0.500000
# 20148    0.238844
# 20149    0.238844
# 20150    0.333333
# 20151    0.000000
# 20152    0.000000
# 20153    0.000000
# 20154    0.000000
# 20155    0.000000
# 20156    0.194700
# 20157    0.000000
# 20158    0.000000
# 20159    0.000000
# 20160    0.000000
# 20161    0.090909
# Length: 20162, dtype: float64

# %%
def add_bleu(df):
    bleu_funcs = [bleu1, bleu2, bleu3, bleu4]
    for col in pred_cols:
        for ngram in range(1,5):
            colname = "%s_bleu%d"%(col[:-5], ngram)
            bleu_func = bleu_funcs[ngram-1]
            df[colname] = df.apply(lambda row: bleu_func(str(row["caption"]), str(row[col])), axis = 1)
    return df

# %%
df_full = add_bleu(df_full)
# Out:
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
reference = [['the', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog']]
candidate = ['the', 'quick', 'brown', 'fox', 'jumped', 'over', 'the']
sentence_bleu(reference, candidate)
# Out:
# 0.7514772930752859

# %%
sentence_bleu(["grilled chicken salad".split()] , "shanghai rainbow chicken".split(), weights=(1.0, 0, 0, 0))
# Out:
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 0.3333333333333333

# %%
df_full.head(100)
# Out:
#                   photo_id                                            caption  \
# 0   _ExrVJTjGcChfzLH51etAw                             shanghai rainbow trout
# 1   yPUPhsJvT6yx6l8QwShw1Q                                grill rainbow trout
# 2   zvESg-w2JIBL5FhU7F2d-g                                       chicken parm
# 3   uqdXqfB8MXW6XU7Hk1gGIQ                                   mcg holiday jazz
# 4   VMedbsDZnCxmCE3Pndvtng                                        dining room
# 5   Y3OxcrMgt_wvxPqVNq5tPg  meatloaf is back topped with bob evans wildfir...
# 6   ACfgPpp3q6oaO0ytpx3cgw                                         quaint bar
# 7   bw1IaF8FVcmShr6xbE0umA          jerk quesadillas and empty crab soup bowl
# 8   q6VRi5FwTMqffR5bsuRumQ                          table seating to the left
# 9   MZ6lyOh87ELi3S3Re3r5IQ                           seafood variety platters
# 10  J4kY0vanHHvkjpim7vr8nA                         crab is fabulous and fresh
# 11  xSz613eZo8w-xeaskD49Hw                             tanks of fresh seafood
# 12  Hg5ccIqxc_hBOFSYVH_zlg                                 yang zhou chao fan
# 13  nmSUbbG76FbPRTCPG7NTdA                                    the arizona sun
# 14  g3go6_1SMFFp6eMZCjCHkQ                                   main dining area
# 15  i52-1DaE8XRyDbrJ-5aTDQ                                         ika mentai
# 16  JtZt13ybK4dfMotLmav55g  note the manekiniko the beckoning cat has both...
# 17  8WJ37XdGFEChjTQ65MzvFg                                          udon suki
# 18  iyiFyYl_cESqwG6MfpCNDw                                            dessert
# 19  nGaIoK6FbFWCBAzjoxuS6A                                           ebi soba
# 20  0e95mE6Mx4-Y-wnI7kIGcA                                       crunchy roll
# 21  aoX1BBSbDawcqSMUaf48NQ                                          udon saki
# 22  795n_ZFZFum0R6IMXv4iow                             gyoza  takeout edition
# 23  RGDjXjd8J3W-DvmuDZaR4g                                       room service
# 24  n6pYfBnt5U9gA8SsEYX8lw     this hotdog has bacon your argument is invalid
# 25  AMFqnzIe4rz4tD8LkzVC-g         the outdoor seating area near the entrance
# 26  XegMWTM7cLo0HwyFPN8-4Q                               the main dining room
# 27  YSixHEXmKUt47ws43y1ckA                                           drooling
# 28  OMTBDMcAGzHxar65qIG7fQ                    com ga ro ti not very flavorful
# 29  zklovsLfAQW6Ag8ioWAK2g  the order bo nuong tom vi is the bomb here if ...
# ..                     ...                                                ...
# 70  O-JyAhmVCq2PYzbrN6YXgw  theres where the beer is made behind the glass...
# 71  qGGKkDi_b3jRKMyd7TLf4g                                    room  num  view
# 72  Cjw-SYIGOURaNgy3YB7I9A             chocolate cake or brownie of some sort
# 73  tcpjFKWdLrHzzUujORqsEQ                         pork belly dim sum awesome
# 74  OoFnC11Chs3LddnWhYU-Fw                          chocolate souffle yum ono
# 75  iGefVUYU9dq5WC7yGjanJg  skyscraper chicago fries yes under all this de...
# 76  aUWgMJKA8_8BIsWRL2DOcQ                            geebees is closed oh no
# 77  4ug7V8ep_SsNfFzuZi4pGw                                spicy fried chicken
# 78  qCEJ7YEpxHzt5H5y_Q1-Lw                           grilled chicken gyro yum
# 79  SnSzAsipTu410l8XGCyouw  alpine swiss chicken wrap  hundreds of amazing...
# 80  IJ_gsLpEKZVa-yl7mOM--Q                  bbq shrimp with rosemary biscuits
# 81  5i2NjsWBfJwOfy8nmfpi_w                  cider brined double cut pork chop
# 82  OnWOsyg-HlFh8_xFxRMGAA                        cedar camp fire plank steak
# 83  RQ96S8jLoa9VYU-c1t4Tcg                                         bbq shrimp
# 84  SXVZ2eNglIexXlETW3_WNw                            classic shrimp cocktail
# 85  l3X2RU4K9So7zpRPyE47Og  make sure to order the banana bread pudding ea...
# 86  WaHmE20QT2YWwn9Zrfum5Q                            artery clogger headwich
# 87  dQaJZ87H8SAlFt-ZLg4ChQ                                tuna steak sandwich
# 88  0WEM3KzBtwBq21232FDDwQ    pierogies and south side steak and egg headwich
# 89  0DzAfTvogv9eRhS8YnEaBw                                            outside
# 90  28HjevwF_dP-3FFr8ndl9Q                                       tram walkway
# 91  _CW-bzXiQo3bomtOvvvjnQ                              luxor june  num  pool
# 92  xac-8PZLSEUf8SQeKVRBng                              luxor june  num  pool
# 93  4wD1e7vhuhOJ1b6hLZ09hA                         view outside of the window
# 94  4bV9uH4Bu6PyKD4Zs1VBXg                queen east tower room  num th floor
# 95  B7FqZNUJZw3Qeiiz-Cit6Q                                      pyramid suite
# 96  FHv3uxskQugJAyMoqF4pmw                                        luxor tower
# 97  XNAq4dgYZMMD2Oy5WH_Ezg  fines herbs omelet at bouchon at the venetian ...
# 98  8bITdFwTRU6IaqY04Ij-3g        poitrine de veau slow cooked veil  num  num
# 99  xpIPtnSj-qmV4OpoL2U2ww                              chicken  and  waffles
#
#                                   merge_concat_6_pred  \
# 0   chicken and waffles served with a side of mac ...
# 1   chicken and waffles served with a side of mac ...
# 2   chicken and waffles served with a side of mac ...
# 3                                   my fav in the bar
# 4                                         dining area
# 5   meatloaf is back topped with bob evans wildfir...
# 6                                         dining area
# 7   chicken and waffles served with a side of mac ...
# 8                                         dining area
# 9                                 chicken and waffles
# 10  chicken and waffles served with a side of mac ...
# 11                                        dining area
# 12  the most popular in the best poutine ive ever ...
# 13  chicken and waffles served with a side of mac ...
# 14                                        dining area
# 15                      spaghetti with homemade sauce
# 16                                           bar area
# 17                                chicken and waffles
# 18  the most of the best ever ive ever had in the ...
# 19                                chicken and waffles
# 20                                    california roll
# 21                                   spicy miso ramen
# 22  the most of the dining room at the new york la...
# 23                                        dining room
# 24                                chicken and waffles
# 25                       outdoor seating at the patio
# 26                                           bar area
# 27                 snow crab legs and king crab claws
# 28  chicken and waffles served with a side of mac ...
# 29  the most of the dining room at the new york la...
# ..                                                ...
# 70                                           bar area
# 71  view from the top level of the strip the resta...
# 72                               red velvet lava cake
# 73  chicken and waffles served with a side of baco...
# 74  red velvet lava cake pudding with vanilla ice ...
# 75  chicken and waffles served with a side of mac ...
# 76  the front of the restaurant in the background ...
# 77  chicken and waffles served with a side of our ...
# 78                               chicken avocado wrap
# 79  chicken and waffles served with a side of baco...
# 80  chicken and waffles served with a side of grav...
# 81             lamb chops with a side of garlic sauce
# 82                                 grilled lamb chops
# 83  roasted prime rib eye steak with a side of cre...
# 84  chicken and waffles served with a side of mac ...
# 85  chicken and waffles served with a side of mac ...
# 86                                 bacon cheeseburger
# 87                                     fish and chips
# 88  delicious food at queen park social at the bal...
# 89                            front of the restaurant
# 90  the venetian las vegas at the paradise valley ...
# 91                    view from the lake at the patio
# 92                    view from the patio at the pool
# 93                                view from the patio
# 94  the grand room to the king bed in the upgraded...
# 95  the grand room at the hazelton tower in the ba...
# 96                view from the lake pool at the pool
# 97    chicken and waffles served with a side of salad
# 98  chicken and waffles served with a side of mac ...
# 99  chicken and waffles served with a side of baco...
#
#                                   merge_concat_7_pred  \
# 0   chicken and waffles served with a side of mac ...
# 1   chicken and waffles served with a side of mac ...
# 2   chicken and waffles served with a side of mac ...
# 3   my fav in the bar at the background of the bes...
# 4                                         dining area
# 5   meatloaf is back topped with bob evans wildfir...
# 6                                         dining area
# 7   chicken and waffles served with a side of mac ...
# 8                                         dining area
# 9   chicken and waffles with a side of mac n chees...
# 10  chicken and waffles served with a side of mac ...
# 11                                        dining area
# 12  the most popular in the best poutine ive ever ...
# 13  chicken and waffles served with a side of mac ...
# 14                                        dining area
# 15               spaghetti with homemade tomato sauce
# 16                                           bar area
# 17  chicken and waffles with a side of mac n chees...
# 18  the most of the best ever ive ever had in town...
# 19                               chicken tikka masala
# 20                                    california roll
# 21                                   spicy miso ramen
# 22  the most of the dining room at the new york la...
# 23                                        dining room
# 24                                chicken and waffles
# 25  outdoor seating at the back to the patio in th...
# 26                                           bar area
# 27                 snow crab legs and king crab claws
# 28  chicken and waffles served with a side of mac ...
# 29  the most of the dining room at the new york la...
# ..                                                ...
# 70                                           bar area
# 71  view from the top level of the strip the resta...
# 72  red velvet lava cake with vanilla ice cream an...
# 73  chicken and waffles served with a side of baco...
# 74  red velvet lava cake pudding with vanilla ice ...
# 75  chicken and waffles served with a side of mac ...
# 76  the front of the restaurant in the background ...
# 77  chicken and waffles served with a side of our ...
# 78                               chicken avocado wrap
# 79  chicken and waffles served with a side of baco...
# 80  chicken and waffles served with a side of grav...
# 81  lamb chops with a side of horseradish sauce an...
# 82     grilled lamb chops with a side of garlic sauce
# 83  roasted prime rib eye steak with a side of cre...
# 84  chicken and waffles served with a side of mac ...
# 85  chicken and waffles served with a side of mac ...
# 86  bacon and bacon burger served with a side of f...
# 87                                     fish and chips
# 88  delicious food at queen park social at the bal...
# 89                            front of the restaurant
# 90              the view from the top of the building
# 91                    view from the lake at the patio
# 92                    view from the patio at the pool
# 93         view from the patio view of the strip view
# 94  the grand room to the king bed room in the gol...
# 95  the grand room at the hazelton tower in the ba...
# 96                view from the lake pool at the pool
# 97    chicken and waffles served with a side of salad
# 98  chicken and waffles served with a side of mac ...
# 99  chicken and waffles served with a side of baco...
#
#                                   merge_concat_8_pred  \
# 0   chicken and waffles served with a side of mac ...
# 1   chicken and waffles served with a side of mac ...
# 2   chicken and waffles served with a side of mac ...
# 3   my fav in the bar at the background of the bes...
# 4     dining area at the back of the main dining room
# 5   meatloaf is back topped with bob evans wildfir...
# 6                         bar area at the dining area
# 7   chicken and waffles served with a side of mac ...
# 8     dining area at the back of the main dining room
# 9   chicken and waffles with a side of mac n chees...
# 10  chicken and waffles served with a side of mac ...
# 11    dining area at the back of the main dining room
# 12  the most of the best ever ive ever had in the ...
# 13  chicken and waffles served with a side of mac ...
# 14  dining area at the back of the dining room wit...
# 15  spaghetti di vongole with clams and tomato sau...
# 16                                           bar area
# 17  chicken and waffles with a side of mac n chees...
# 18  the most of the best ever ive ever had in town...
# 19  chicken tikka masala with a side of rice on th...
# 20  california roll with spicy tuna roll topped wi...
# 21   spicy miso ramen with hot pot on a side of sauce
# 22  the most of the dining room at the new york la...
# 23  dining room at the ballantyne steakhouse in th...
# 24                                chicken and waffles
# 25  outdoor seating at the back to the patio in th...
# 26                                bar area at the bar
# 27                 snow crab legs and king crab claws
# 28  chicken and waffles served with a side of mac ...
# 29  the most of the dining room at the new york la...
# ..                                                ...
# 70                                bar area at the bar
# 71  view from the top level of the strip the resta...
# 72  red velvet lava cake with vanilla ice cream an...
# 73  chicken and waffles served with a side of our ...
# 74  red velvet lava cake pudding with vanilla ice ...
# 75  chicken and waffles served with a side of mac ...
# 76  inside the front of the restaurant at the back...
# 77  chicken and waffles served with a side of our ...
# 78  chicken avocado wrap with a side of greek sala...
# 79  chicken and waffles served with a side of baco...
# 80  chicken and waffles served with a side of grav...
# 81  lamb chops with a side of horseradish sauce an...
# 82     grilled lamb chops with a side of garlic sauce
# 83  roasted prime rib eye steak with a side of our...
# 84  chicken and waffles served with a side of mac ...
# 85  chicken and waffles served with a side of mac ...
# 86  bacon and bacon burger served with a side of f...
# 87  fish and chips for a side of the best food in ...
# 88  delicious food at queen park social at the bal...
# 89                            front of the restaurant
# 90              the view from the top of the building
# 91                    view from the lake at the patio
# 92                    view from the patio at the pool
# 93     view from the patio view of the strip the view
# 94  the grand room to the king bed room in the gol...
# 95  the grand room at the hazelton tower in the ba...
# 96  view from the lake pool at the pool view of th...
# 97  chicken and waffles served with a side of our ...
# 98  chicken and waffles served with a side of mac ...
# 99  chicken and waffles served with a side of our ...
#
#                                      merge_add_6_pred  \
# 0                               grilled chicken salad
# 1                 the best breakfast ever had so good
# 2                                 fried chicken salad
# 3                                      the best patio
# 4                                         dining room
# 5   meatloaf is back topped with bob evans wildfir...
# 6                                         dining room
# 7                                 chicken and waffles
# 8                                         dining room
# 9      pad kee mao chicken fried rice and spicy sauce
# 10                          fried chicken and waffles
# 11                                        dining room
# 12                          fried chicken and waffles
# 13               fried rice with rice and spicy sauce
# 14                                           bar area
# 15                       pad thai with chicken noodle
# 16                                           bar area
# 17  spicy miso ramen with rice and spicy sauce thi...
# 18                              salmon skin hand roll
# 19      spicy miso ramen with chicken and spicy sauce
# 20                                    spicy tuna roll
# 21  pork belly soup this is a must be you can see ...
# 22                          fried chicken and waffles
# 23                                           bar area
# 24                          fried chicken and waffles
# 25                                view from the patio
# 26                                        dining room
# 27  crab legs with crab and crab meat and mussels ...
# 28                                  spicy salmon roll
# 29                        lunch buffet for two people
# ..                                                ...
# 70                                           bar area
# 71                                view from our table
# 72  chocolate chip cookie ice cream and chocolate ...
# 73                          fried chicken and waffles
# 74  chocolate chip cookie ice cream and chocolate ...
# 75                          fried chicken and waffles
# 76                             view of the restaurant
# 77                          fried chicken and waffles
# 78  grilled chicken sandwich with fries and eggs a...
# 79                the best breakfast ever had so good
# 80                                fried chicken wings
# 81                                        duck breast
# 82                                        duck breast
# 83                                        duck breast
# 84  fish and chips and mac n cheese and beer batte...
# 85                                chicken and waffles
# 86                                         bbq burger
# 87  sweet potato fries with fries and cheese curds...
# 88                          fried chicken and waffles
# 89  front of parking lot of th avenue of the corne...
# 90                                view from the patio
# 91                                view from the patio
# 92                                view from the patio
# 93                                view from our table
# 94                                              suite
# 95                                              suite
# 96                                view from the patio
# 97                               salmon sashimi salad
# 98                          fried chicken and waffles
# 99                          fried chicken and waffles
#
#                                      merge_add_7_pred  \
# 0                               grilled chicken salad
# 1                 the best breakfast ever had so good
# 2                                 fried chicken salad
# 3                                      the best patio
# 4                                         dining room
# 5   meatloaf is back topped with bob evans wildfir...
# 6                                         dining room
# 7                                 chicken and waffles
# 8                                         dining room
# 9   pad kee mao chicken fried rice and spicy sauce...
# 10                          fried chicken and waffles
# 11                                        dining room
# 12  fried chicken and waffles with maple syrup and...
# 13               fried rice with rice and spicy sauce
# 14                              inside the restaurant
# 15       pad thai with chicken noodle and spicy sauce
# 16                                           bar area
# 17  spicy miso ramen with rice and spicy sauce thi...
# 18    salmon sashimi tuna sashimi and spicy tuna roll
# 19  spicy miso ramen with chicken and spicy sauce ...
# 20                                    spicy tuna roll
# 21  pork belly soup this is a must be you can see ...
# 22  fried chicken and waffles with maple syrup and...
# 23                                           bar area
# 24  fried chicken and waffles with maple syrup and...
# 25                                view from the patio
# 26                                        dining room
# 27  crab legs with crab and crab claws crab meat a...
# 28                                  spicy salmon roll
# 29                        lunch buffet for two people
# ..                                                ...
# 70                                           bar area
# 71                           view from our table room
# 72  chocolate chip cookie ice cream and chocolate ...
# 73  fried chicken and waffles with fried eggs and ...
# 74  chocolate chip cookie ice cream and chocolate ...
# 75                          fried chicken and waffles
# 76                             view of the restaurant
# 77  fried chicken and waffles with maple syrup and...
# 78  grilled chicken sandwich with fries and eggs a...
# 79                the best breakfast ever had so good
# 80  fried chicken and waffles with mashed potatoes...
# 81  duck breast with mashed potatoes and spinach a...
# 82  duck breast and rib eye steak with a side of m...
# 83                                        duck breast
# 84  fish and chips and mac n cheese and beer batte...
# 85  chicken and waffles with mashed potatoes and b...
# 86                                         bbq burger
# 87  sweet potato fries with fries and cheese curds...
# 88  fried chicken and waffles with maple syrup and...
# 89  front of parking lot of th avenue of the corne...
# 90                                view from the patio
# 91                                view from the patio
# 92                                view from the patio
# 93                                view from our table
# 94                                              suite
# 95                                              suite
# 96                                view from the patio
# 97                               salmon sashimi salad
# 98                          fried chicken and waffles
# 99                          fried chicken and waffles
#
#                                      merge_add_8_pred  \
# 0   grilled chicken salad with chicken and peas an...
# 1   the best breakfast ever had so good and this p...
# 2   fried chicken and chicken breast and peppers a...
# 3   the best patio and great food and friendly ser...
# 4                                         dining room
# 5   meatloaf is back topped with bob evans wildfir...
# 6                             view of the dining room
# 7   fried chicken and waffles and eggs benny eggs ...
# 8                             view of the dining area
# 9   pad kee mao chicken fried rice and spicy sauce...
# 10                          fried chicken and waffles
# 11                            view of the dining area
# 12  fried chicken and waffles and eggs and biscuit...
# 13  fried rice with rice and spicy sauce and veggi...
# 14  inside the restaurant with lots of tvs and sea...
# 15       pad thai with chicken noodle and spicy sauce
# 16  bar area with lots of tvs and beer and whiskey...
# 17  spicy miso ramen with rice and spicy sauce thi...
# 18  salmon sashimi tuna sashimi and spicy tuna rol...
# 19  spicy miso ramen with chicken and spicy sauce ...
# 20              spicy tuna roll and spicy salmon roll
# 21  pork belly soup this is a must be you can see ...
# 22  fried chicken and waffles and eggs and biscuit...
# 23  bar area with a side of side dishes and mac n ...
# 24  fried chicken and waffles and butter biscuit a...
# 25                                view from the patio
# 26                                        dining room
# 27  crab legs with crab and crab claws crab meat a...
# 28  spicy salmon and spicy tuna roll with ponzu ma...
# 29  lunch buffet for two people and go for your fa...
# ..                                                ...
# 70                                           bar area
# 71  view from our table of the strip and the bella...
# 72  fried ice cream with cream cheese frosting and...
# 73  fried chicken and waffles with fried eggs and ...
# 74  chocolate chip cookie ice cream and chocolate ...
# 75  fried chicken and waffles and eggs and biscuit...
# 76                             view of the restaurant
# 77  fried chicken and waffles with maple syrup and...
# 78  grilled chicken sandwich with fries and cheese...
# 79  the best breakfast ever had so good and this p...
# 80  fried chicken and waffles with mashed potatoes...
# 81  duck breast with mashed potatoes and spinach a...
# 82  duck breast and rib eye steak with a side of m...
# 83  duck breast with mashed potatoes and spinach a...
# 84  fish and chips and mac n cheese and beer batte...
# 85  chicken and waffles with a side of mac n chees...
# 86  bbq burger with fries and fries lettuce and bb...
# 87  sweet potato fries with fries and cheese curds...
# 88  fried chicken and waffles and eggs and biscuit...
# 89  front of parking lot of th avenue of the corne...
# 90                           view from the patio area
# 91                                view from the patio
# 92                                view from the patio
# 93  view from our table of the strip and the bella...
# 94                                              suite
# 95                                              suite
# 96                                view from the patio
# 97  salmon skin hand roll w ponzu sauce and spicy ...
# 98  fried chicken and waffles and biscuits and but...
# 99  fried chicken and waffles with maple syrup and...
#
#                                         inject_6_pred  \
# 0                                           beef stew
# 1                               salmon skin hand roll
# 2                                 spicy chicken pizza
# 3                                  mademoiselle shows
# 4                                         dining room
# 5   meatloaf is back topped with bob evans wildfir...
# 6                                            bar area
# 7                                     pork belly buns
# 8                                         dining room
# 9                                            pad thai
# 10                        grilled chicken and waffles
# 11                              inside the restaurant
# 12                               chicken caesar salad
# 13                               spicy tuna poke bowl
# 14                                           bar area
# 15                                shrimp scampi pasta
# 16                                           bar area
# 17                                    pork belly soup
# 18                                       tuna tartare
# 19                                    pork belly soup
# 20                                        salmon roll
# 21                                    pork belly soup
# 22                                chicken and waffles
# 23                                private dining room
# 24                                         sushi roll
# 25                                    outdoor seating
# 26                                        dining room
# 27                                chicken and waffles
# 28                                    pork belly soup
# 29  this is the best food ive ever had it was amazing
# ..                                                ...
# 70                                  view from the bar
# 71                                view from the patio
# 72              chocolate cake with vanilla ice cream
# 73                                chicken and waffles
# 74  chocolate brownie sundae vanilla ice cream and...
# 75                                chicken and waffles
# 76                            front of the restaurant
# 77                          fried chicken and waffles
# 78                                   chicken sandwich
# 79                                       chicken wrap
# 80                                      chicken wings
# 81                                       filet mignon
# 82                                         lamb chops
# 83                                         lamb chops
# 84                                chicken and waffles
# 85                                chicken and waffles
# 86                                 bacon cheeseburger
# 87                               pulled pork sandwich
# 88                                chicken and waffles
# 89                                           exterior
# 90                                   from the website
# 91                                view from the patio
# 92                                view from the patio
# 93                                view from the patio
# 94                                private dining room
# 95                                        living room
# 96                                view from the patio
# 97                                              salad
# 98                                         lamb chops
# 99                                         lamb chops
#
#                                         inject_7_pred       ...        \
# 0                                   salmon skin salad       ...
# 1                               salmon skin hand roll       ...
# 2                                 spicy chicken pizza       ...
# 3                       mademoiselle shows at the bar       ...
# 4                                         dining room       ...
# 5   meatloaf is back topped with bob evans wildfir...       ...
# 6                                            bar area       ...
# 7                                     pork belly buns       ...
# 8                                         dining room       ...
# 9                                            pad thai       ...
# 10                        grilled chicken and waffles       ...
# 11                              inside the restaurant       ...
# 12                               chicken caesar salad       ...
# 13                               spicy tuna poke bowl       ...
# 14                                           bar area       ...
# 15                                shrimp scampi pasta       ...
# 16                                           bar area       ...
# 17                                    pork belly soup       ...
# 18                                       tuna tartare       ...
# 19                                    pork belly soup       ...
# 20                                        salmon roll       ...
# 21                                    pork belly soup       ...
# 22                                chicken and waffles       ...
# 23                                private dining room       ...
# 24                                         sushi roll       ...
# 25                               outdoor seating area       ...
# 26                                        dining room       ...
# 27                                chicken and waffles       ...
# 28                                    pork belly soup       ...
# 29  this is the best food ive ever had it was amazing       ...
# ..                                                ...       ...
# 70               view from the bar at the dining room       ...
# 71                     view from the patio at the bar       ...
# 72              chocolate cake with vanilla ice cream       ...
# 73                                chicken and waffles       ...
# 74  chocolate brownie sundae vanilla ice cream and...       ...
# 75                                chicken and waffles       ...
# 76                            front of the restaurant       ...
# 77  fried chicken and waffles with a side of mac n...       ...
# 78                              chicken club sandwich       ...
# 79      chicken wrap with a side of chicken and salad       ...
# 80                                chicken and waffles       ...
# 81    filet mignon with sweet potato and garlic sauce       ...
# 82                                         lamb chops       ...
# 83                                         lamb chops       ...
# 84                                chicken and waffles       ...
# 85                                chicken and waffles       ...
# 86                                 bacon cheeseburger       ...
# 87                               pulled pork sandwich       ...
# 88  chicken and waffles with a side of mac n chees...       ...
# 89                                           exterior       ...
# 90                                   from the website       ...
# 91                     view from the patio at the bar       ...
# 92                     view from the patio at the bar       ...
# 93                     view from the patio at the bar       ...
# 94                                private dining room       ...
# 95                                        living room       ...
# 96                     view from the patio at the bar       ...
# 97                                              salad       ...
# 98                                         lamb chops       ...
# 99                                         lamb chops       ...
#
#    inject_6_bleu3  inject_6_bleu4  inject_7_bleu1  inject_7_bleu2  \
# 0    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 1    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 2   6.191520e-204   1.384293e-231        0.333333   8.612150e-155
# 3    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 4   2.982797e-102   1.491668e-154        1.000000    1.000000e+00
# 5    1.000000e+00    1.000000e+00        1.000000    1.000000e+00
# 6   7.077949e-204   1.531972e-231        0.500000   1.054769e-154
# 7    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 8    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 9    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 10  4.385245e-204   1.003274e-231        0.194700   5.808562e-155
# 11   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 12   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 13   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 14  4.292993e-204   9.291880e-232        0.303265   6.397495e-155
# 15   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 16   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 17   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 18   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 19   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 20  7.077949e-204   1.531972e-231        0.500000   1.054769e-154
# 21   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 22   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 23  6.191520e-204   1.384293e-231        0.333333   8.612150e-155
# 24   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 25  2.448429e-103   1.224436e-155        0.263597    2.635971e-01
# 26  1.097310e-102   5.487540e-155        0.367879    3.678794e-01
# 27   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 28   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 29  2.924216e-103   2.015056e-155        0.066887    4.960485e-02
# ..            ...             ...             ...             ...
# 70  1.256394e-204   2.874429e-232        0.194700   5.808562e-155
# 71  5.630767e-204   1.288230e-231        0.142857   5.637976e-155
# 72  1.033073e-102   6.416039e-155        0.282161    2.185606e-01
# 73   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 74  4.308710e-204   1.051835e-231        0.090909   4.497549e-155
# 75   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 76   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 77  1.651330e-102   9.530911e-155        0.153846    1.132277e-01
# 78  2.603832e-204   5.635810e-232        0.238844   6.170875e-155
# 79  7.393614e-105   3.697476e-157        0.191251    1.171169e-01
# 80   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 81   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 82   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 83   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 84   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 85  1.488253e-207   3.327418e-235        0.000080   2.070098e-158
# 86   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 87  6.191520e-204   1.384293e-231        0.333333   8.612150e-155
# 88  1.169427e-204   2.614592e-232        0.214286   6.905082e-155
# 89   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 90   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 91   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 92   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 93  5.512312e-204   1.193101e-231        0.285714   7.973302e-155
# 94  1.632067e-204   3.648957e-232        0.087866   2.270138e-155
# 95   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 96   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 97   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 98   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 99   0.000000e+00    0.000000e+00        0.000000    0.000000e+00
#
#     inject_7_bleu3  inject_7_bleu4  inject_8_bleu1  inject_8_bleu2  \
# 0     0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 1     0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 2    6.191520e-204   1.384293e-231        0.166667   6.089710e-155
# 3     0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 4    2.982797e-102   1.491668e-154        1.000000    1.000000e+00
# 5     1.000000e+00    1.000000e+00        1.000000    1.000000e+00
# 6    7.077949e-204   1.531972e-231        0.500000   1.054769e-154
# 7     0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 8     0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 9     0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 10   4.385245e-204   1.003274e-231        0.076923   4.137143e-155
# 11    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 12    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 13    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 14   4.292993e-204   9.291880e-232        0.222222   7.031791e-155
# 15    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 16    0.000000e+00    0.000000e+00        0.163746   5.461706e-155
# 17    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 18    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 19    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 20   7.077949e-204   1.531972e-231        0.500000   1.054769e-154
# 21    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 22    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 23   6.191520e-204   1.384293e-231        0.333333   8.612150e-155
# 24    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 25    2.635971e-01    3.219414e-78        0.263597    2.635971e-01
# 26   1.097310e-102   5.487540e-155        0.367879    3.678794e-01
# 27    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 28    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 29   2.924216e-103   2.015056e-155        0.066887    4.960485e-02
# ..             ...             ...             ...             ...
# 70   4.385245e-204   1.003274e-231        0.181818   6.360494e-155
# 71   4.681284e-204   1.120041e-231        0.142857   5.637976e-155
# 72   1.033073e-102   6.416039e-155        0.142857   5.637976e-155
# 73    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 74   4.032624e-204   1.000369e-231        0.090909   4.497549e-155
# 75    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 76    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 77   7.083248e-103   5.019363e-155        0.153846    1.132277e-01
# 78   4.436418e-204   9.918892e-232        0.100000   4.717069e-155
# 79   5.996243e-103   3.866738e-155        0.191251    1.171169e-01
# 80    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 81    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 82    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 83    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 84    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 85   1.488253e-207   3.327418e-235        0.066120    3.484807e-02
# 86    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 87   6.191520e-204   1.384293e-231        0.083333   4.306075e-155
# 88   5.351495e-204   1.239529e-231        0.214286   6.905082e-155
# 89    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 90    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 91    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 92    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 93   5.884436e-204   1.331960e-231        0.272727   7.789983e-155
# 94   1.632067e-204   3.648957e-232        0.087866   2.270138e-155
# 95    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 96    0.000000e+00    0.000000e+00        0.090909   4.497549e-155
# 97    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 98    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
# 99    0.000000e+00    0.000000e+00        0.000000    0.000000e+00
#
#     inject_8_bleu3  inject_8_bleu4
# 0     0.000000e+00    0.000000e+00
# 1     0.000000e+00    0.000000e+00
# 2    4.925580e-204   1.164047e-231
# 3     0.000000e+00    0.000000e+00
# 4    2.982797e-102   1.491668e-154
# 5     1.000000e+00    1.000000e+00
# 6    7.077949e-204   1.531972e-231
# 7     0.000000e+00    0.000000e+00
# 8     0.000000e+00    0.000000e+00
# 9     0.000000e+00    0.000000e+00
# 10   3.816331e-204   9.594503e-232
# 11    0.000000e+00    0.000000e+00
# 12    0.000000e+00    0.000000e+00
# 13    0.000000e+00    0.000000e+00
# 14   5.416106e-204   1.250850e-231
# 15    0.000000e+00    0.000000e+00
# 16   4.282805e-204   9.974863e-232
# 17    0.000000e+00    0.000000e+00
# 18    0.000000e+00    0.000000e+00
# 19    0.000000e+00    0.000000e+00
# 20   7.077949e-204   1.531972e-231
# 21    0.000000e+00    0.000000e+00
# 22    0.000000e+00    0.000000e+00
# 23   6.191520e-204   1.384293e-231
# 24    0.000000e+00    0.000000e+00
# 25    2.635971e-01    3.219414e-78
# 26   1.097310e-102   5.487540e-155
# 27    0.000000e+00    0.000000e+00
# 28    0.000000e+00    0.000000e+00
# 29   2.924216e-103   2.015056e-155
# ..             ...             ...
# 70   5.069062e-204   1.189646e-231
# 71   4.681284e-204   1.120041e-231
# 72   4.681284e-204   1.120041e-231
# 73    0.000000e+00    0.000000e+00
# 74   4.032624e-204   1.000369e-231
# 75    0.000000e+00    0.000000e+00
# 76    0.000000e+00    0.000000e+00
# 77   7.083248e-103   5.019363e-155
# 78   4.161475e-204   1.024491e-231
# 79   5.996243e-103   3.866738e-155
# 80    0.000000e+00    0.000000e+00
# 81    0.000000e+00    0.000000e+00
# 82    0.000000e+00    0.000000e+00
# 83    0.000000e+00    0.000000e+00
# 84    0.000000e+00    0.000000e+00
# 85   1.764710e-103   1.132131e-155
# 86    0.000000e+00    0.000000e+00
# 87   3.918479e-204   9.788429e-232
# 88   5.351495e-204   1.239529e-231
# 89    0.000000e+00    0.000000e+00
# 90    0.000000e+00    0.000000e+00
# 91    0.000000e+00    0.000000e+00
# 92    0.000000e+00    0.000000e+00
# 93   5.794791e-204   1.316559e-231
# 94   1.632067e-204   3.648957e-232
# 95    0.000000e+00    0.000000e+00
# 96   4.032624e-204   1.000369e-231
# 97    0.000000e+00    0.000000e+00
# 98    0.000000e+00    0.000000e+00
# 99    0.000000e+00    0.000000e+00
#
# [100 rows x 47 columns]

# %%
df_full.iloc[85].caption
# Out:
# 'make sure to order the banana bread pudding early as you make your meal order  it is made fresh per order and can take  num  mins to prepare'
